# %%
input('请输入一个整数')
# Out:
# 请输入一个整数 123
# '123'

# %%
input("Input a number: \n")
# Out:
# Input a number:
#  100
# '100'

# %%
var1 = input("第一行内容")
var2 = input("第二行内容")
print(var2)
print(var1)
# Out:
# 第一行内容 hello
# 第二行内容 world
# world
# hello
